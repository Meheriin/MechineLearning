# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=610295346657f59abd2cd158fff9ae98&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[
    ['id','title','overview','release_date','popularity','vote_average','vote_count']
]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     33.0609
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     31.0195
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     16.4137
# 3  The true story of how businessman Oskar Schind...   1993-12-15     14.9015
# 4  The defense and the prosecution have rested an...   1957-04-10     11.0014
#
#    vote_average  vote_count
# 0         8.714       29408
# 1         8.685       22196
# 2         8.571       13419
# 3         8.565       16938
# 4         8.549        9607

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 429):
    response = requests.get(
        'https://api.themoviedb.org/3/movie/top_rated?api_key=610295346657f59abd2cd158fff9ae98&language=en-US&page={}'.format(i)
    )
    
    temp_df = pd.DataFrame(response.json()['results'])[
        ['id','title','overview','release_date','popularity','vote_average','vote_count']
    ]
    df = pd.concat([df, temp_df], ignore_index=True)

print(df.shape)
# Out:
# (8560, 7)

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  168055        Love Is in the Air
# 8556   37821                   Killers
# 8557   12245        The Oxford Murders
# 8558  257440                 Term Life
# 8559   97051          Would You Rather
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
